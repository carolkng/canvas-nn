# %%
import requests
import yaml

secrets = yaml.safe_load(open("secrets.yaml"))
headers = {"Authorization": "Bearer %s" % secrets["token"]}
r = requests.get("https://canvas.ubc.ca/api/v1/courses/", headers=headers)

# %%
r.json()
# Out:
# [{'id': 12111,
#   'name': 'APSC 450 101 Professional Engineering Practice',
#   'account_id': 117,
#   'uuid': 'huLP9958RWpGmudXmJTaymIatNOlOpg25iFfaBSg',
#   'start_at': '2018-09-11T17:18:14Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2018-05-23T19:32:58Z',
#   'course_code': 'APSC 450 101',
#   'default_view': 'wiki',
#   'root_account_id': 1,
#   'enrollment_term_id': 8,
#   'end_at': None,
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 4000,
#   'is_public_to_auth_users': False,
#   'apply_assignment_group_weights': False,
#   'locale': 'en-GB',
#   'calendar': {'ics': 'https://canvas.ubc.ca/feeds/calendars/course_huLP9958RWpGmudXmJTaymIatNOlOpg25iFfaBSg.ics'},
#   'time_zone': 'America/Los_Angeles',
#   'blueprint': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 3,
#     'user_id': 34456,
#     'enrollment_state': 'active'}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 22596,
#   'name': 'CIVL 250 99A Engineering and Sustainable Development',
#   'account_id': 131,
#   'uuid': '9xt8bbNQYDLTR1L6LNKrMxtUjW4xLwTi5SLKv5th',
#   'start_at': '2018-08-24T18:18:00Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2018-05-25T18:06:09Z',
#   'course_code': 'CIVL 250 99A',
#   'default_view': 'modules',
#   'root_account_id': 1,
#   'enrollment_term_id': 8,
#   'end_at': None,
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 4000,
#   'is_public_to_auth_users': False,
#   'apply_assignment_group_weights': True,
#   'calendar': {'ics': 'https://canvas.ubc.ca/feeds/calendars/course_9xt8bbNQYDLTR1L6LNKrMxtUjW4xLwTi5SLKv5th.ics'},
#   'time_zone': 'America/Los_Angeles',
#   'blueprint': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 3,
#     'user_id': 34456,
#     'enrollment_state': 'active'}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 9390,
#   'name': 'CPSC 259 101 Data Structures and Algorithms for Electrical Engineers',
#   'account_id': 267,
#   'uuid': 'yJLRkq4MmlZFf9cCOzZLh4ojPvdhaBR0a1QXmbkY',
#   'start_at': '2018-09-10T19:08:08Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2018-03-08T23:56:47Z',
#   'course_code': 'CPSC259.101',
#   'default_view': 'assignments',
#   'root_account_id': 1,
#   'enrollment_term_id': 8,
#   'end_at': None,
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 4000,
#   'is_public_to_auth_users': False,
#   'apply_assignment_group_weights': False,
#   'calendar': {'ics': 'https://canvas.ubc.ca/feeds/calendars/course_yJLRkq4MmlZFf9cCOzZLh4ojPvdhaBR0a1QXmbkY.ics'},
#   'time_zone': 'America/Los_Angeles',
#   'blueprint': False,
#   'enrollments': [{'type': 'ta',
#     'role': 'TA Grader',
#     'role_id': 11,
#     'user_id': 34456,
#     'enrollment_state': 'active'}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 3849, 'access_restricted_by_date': True},
#  {'id': 14709,
#   'name': 'MECH 326 Mechanical Design II',
#   'account_id': 119,
#   'uuid': 'pU4aldhKvSEZlHMKwcrPlVsa1U7Rz5OMwHrLztbz',
#   'start_at': '2018-09-04T06:58:41Z',
#   'grading_standard_id': None,
#   'is_public': False,
#   'created_at': '2018-05-24T03:08:32Z',
#   'course_code': 'MECH 326',
#   'default_view': 'wiki',
#   'root_account_id': 1,
#   'enrollment_term_id': 8,
#   'end_at': None,
#   'public_syllabus': False,
#   'public_syllabus_to_auth': False,
#   'storage_quota_mb': 4000,
#   'is_public_to_auth_users': False,
#   'apply_assignment_group_weights': False,
#   'locale': 'en-GB',
#   'calendar': {'ics': 'https://canvas.ubc.ca/feeds/calendars/course_pU4aldhKvSEZlHMKwcrPlVsa1U7Rz5OMwHrLztbz.ics'},
#   'time_zone': 'America/Los_Angeles',
#   'blueprint': False,
#   'enrollments': [{'type': 'student',
#     'role': 'StudentEnrollment',
#     'role_id': 3,
#     'user_id': 34456,
#     'enrollment_state': 'active'}],
#   'hide_final_grades': False,
#   'workflow_state': 'available',
#   'restrict_enrollments_to_course_dates': False},
#  {'id': 2349, 'access_restricted_by_date': True},
#  {'id': 9802, 'access_restricted_by_date': True}]
